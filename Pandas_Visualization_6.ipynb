# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r'C:\Users\balod\Documents\Python Programming\Pandas\Ice Cream Ratings.csv')
df=df.set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
 df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#Line Plot
df.plot(kind= 'line')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind= 'line', subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df.plot(kind= 'line', title= 'Ice Cream Ratings', xlabel= 'Daily Ratings', ylabel= 'Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
#Bar Plot
df.plot(kind= 'bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind= 'bar', stacked=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df['Flavor Rating'].plot(kind= 'bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df['Flavor Rating'].plot(kind= 'barh')
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot.barh()
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot.barh(stacked= True)
# Out:
# <Axes: ylabel='Date'>

# %%
#Scatter plot

df.plot.scatter(x= 'Texture Rating', y= 'Flavor Rating')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Flavor Rating'>

# %%
df.plot.scatter(x= 'Texture Rating', y= 'Flavor Rating',s= 100, c='red')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Flavor Rating'>

# %%
df.plot(kind= 'scatter', x= 'Texture Rating', y= 'Flavor Rating')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Flavor Rating'>

# %%
#Histogram
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind= 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins= 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins= 5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins= 100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Box Plot
df.boxplot()
# Out:
# <Axes: >

# %%
#Area Plot
df.plot.area()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.area(figsize= (5,5))
# Out:
# <Axes: xlabel='Date'>

# %%
#Pie Chart
df.plot.pie(y= 'Flavor Rating', figsize= (10,10))
# Out:
# <Axes: ylabel='Flavor Rating'>

# %%
#Different style of available with matplotlib.pyplot

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('dark_background')
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
plt.style.use('seaborn-v0_8-pastel')
df.plot(kind= 'bar')
# Out:
# <Axes: xlabel='Date'>

# %%
plt.style.use('seaborn-v0_8-ticks')
df.plot(kind= 'barh')
# Out:
# <Axes: ylabel='Date'>

# %%
import pandas as pd

# %%
df= pd. read_csv(r"C:\Users\balod\Documents\Lung Cancer Research\dataset_lung_cancer.csv")

# %%
df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
#Patients having age <=20
df[df['Age'] <=20]
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 1        1        P10   17       1              3            1             5
# 16      16       P112   17       1              3            1             5
# 19      19       P115   14       1              2            4             5
# 27      27       P122   19       1              3            2             4
# 35      35        P13   14       1              2            4             5
# ..     ...        ...  ...     ...            ...          ...           ...
# 931    931       P937   17       2              1            2             3
# 938    938       P943   18       2              3            2             1
# 956    956        P96   18       2              6            8             7
# 986    986       P987   19       1              6            8             7
# 998    998       P998   18       2              6            8             7
#
# ...

# %%
#isin function
#Patients with specified Alcohol use

specific_alcoholUse= [7,8]
df[df['Alcohol use'].isin(specific_alcoholUse)]
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# 10      10       P107   44       1              6            7             7
# 11      11       P108   64       2              6            8             7
# 13      13        P11   34       1              6            7             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 993    993       P993   37       2              7            7             7
# 994    994       P994   33       1              6            7             7
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 998    998       P998   18       2              6            8             7
#
# ...

# %%
#contains function
#-> for a string to check if it contains a particular substring

df[df['Patient Id'].str.contains('11')]
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 13      13        P11   34       1              6            7             7
# 14      14       P110   27       2              3            1             4
# 15      15       P111   73       1              5            6             6
# 16      16       P112   17       1              3            1             5
# 17      17       P113   34       1              6            7             7
# 18      18       P114   36       1              6            7             7
# 19      19       P115   14       1              2            4             5
# 20      20       P116   24       1              6            8             7
# 21      21       P117   53       2              4            5             6
# 22      22       P118   62       1              6            8             7
# 23      23       P119   29       2              6            7             7
# ...

# %%
df2= df.set_index('Level')

# %%
df2
# Out:
#         index Patient Id  Age  Gender  Air Pollution  Alcohol use  \
# Level
# Low         0         P1   33       1              2            4
# Medium      1        P10   17       1              3            1
# High        2       P100   35       1              4            5
# High        3      P1000   37       1              7            7
# High        4       P101   46       1              6            8
# ...       ...        ...  ...     ...            ...          ...
# High      995       P995   44       1              6            7
# High      996       P996   37       2              6            8
# High      997       P997   25       2              4            5
# High      998       P998   18       2              6            8
# High      999       P999   47       1              6            5
#
#         Dust Allergy  OccuPational Hazards  Genetic Risk  \
# Level
# Low                5                     4             3
# ...

# %%
df2.filter(items= ['Patient Id', 'Age'])
# Out:
#        Patient Id  Age
# Level
# Low            P1   33
# Medium        P10   17
# High         P100   35
# High        P1000   37
# High         P101   46
# ...           ...  ...
# High         P995   44
# High         P996   37
# High         P997   25
# High         P998   18
# High         P999   47
#
# [1000 rows x 2 columns]

# %%
df2.filter(items= ['Patient Id', 'Age'], axis=1) 
#axis=0 will give only the headings of columns
#so for columns, axis=1
#and in scase of rows, axis=0
# Out:
#        Patient Id  Age
# Level
# Low            P1   33
# Medium        P10   17
# High         P100   35
# High        P1000   37
# High         P101   46
# ...           ...  ...
# High         P995   44
# High         P996   37
# High         P997   25
# High         P998   18
# High         P999   47
#
# [1000 rows x 2 columns]

# %%
df2.filter(items= ['High'])
# Out:
# Empty DataFrame
# Columns: []
# Index: [Low, Medium, High, High, High, High, Low, Low, Medium, Medium, High, High, Medium, High, Low, Medium, Medium, High, High, Medium, High, High, High, High, High, Medium, Medium, Medium, High, Medium, High, High, Medium, Low, Low, Medium, Low, Low, Low, Low, Low, Low, Low, Low, Low, Low, High, Low, Low, Low, Low, Low, Low, Low, Low, Low, Low, High, Low, Low, Low, Low, Low, Medium, Medium, Medium, Medium, Medium, High, Medium, Medium, Medium, Medium, Medium, Medium, Medium, Medium, Medium, Medium, High, Medium, Medium, Medium, Medium, Medium, Medium, Medium, High, High, High, Medium, High, High, High, High, High, High, High, High, High, ...]
#
# [1000 rows x 0 columns]

# %%
df2.filter(items= ['High'], axis=0) 
#here the duplicates are present so axis=0 doesnt work on duplicates
# Out:
# C:\Users\balod\AppData\Local\Temp\ipykernel_6680\1451193171.py:1: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   df2.filter(items= ['High'], axis=0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df2.filter(items= ['High'], axis=0)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5454, in NDFrame.filter(self, items, like, regex, axis)
#    5452 if items is not None:
#    5453     name = self._get_axis_name(axis)
# -> 5454     return self.reindex(**{name: [r for r in items if r in labels]})
#    5455 elif like:
#    5457     def f(x) -> bool_t:
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:347, in rewrite_axis_style_signature.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     345 @wraps(func)
# ...

# %%
#Like
#doesnt require sqaure brackets like items
df2.filter(like= 'Low')
# Out:
# Empty DataFrame
# Columns: []
# Index: [Low, Medium, High, High, High, High, Low, Low, Medium, Medium, High, High, Medium, High, Low, Medium, Medium, High, High, Medium, High, High, High, High, High, Medium, Medium, Medium, High, Medium, High, High, Medium, Low, Low, Medium, Low, Low, Low, Low, Low, Low, Low, Low, Low, Low, High, Low, Low, Low, Low, Low, Low, Low, Low, Low, Low, High, Low, Low, Low, Low, Low, Medium, Medium, Medium, Medium, Medium, High, Medium, Medium, Medium, Medium, Medium, Medium, Medium, Medium, Medium, Medium, High, Medium, Medium, Medium, Medium, Medium, Medium, Medium, High, High, High, Medium, High, High, High, High, High, High, High, High, High, ...]
#
# [1000 rows x 0 columns]

# %%
df2.filter(like= 'Patient Id', axis=1)
# Out:
#        Patient Id
# Level
# Low            P1
# Medium        P10
# High         P100
# High        P1000
# High         P101
# ...           ...
# High         P995
# High         P996
# High         P997
# High         P998
# High         P999
#
# [1000 rows x 1 columns]

# %%
df2.filter(like= '1', axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [Low, Medium, High, High, High, High, Low, Low, Medium, Medium, High, High, Medium, High, Low, Medium, Medium, High, High, Medium, High, High, High, High, High, Medium, Medium, Medium, High, Medium, High, High, Medium, Low, Low, Medium, Low, Low, Low, Low, Low, Low, Low, Low, Low, Low, High, Low, Low, Low, Low, Low, Low, Low, Low, Low, Low, High, Low, Low, Low, Low, Low, Medium, Medium, Medium, Medium, Medium, High, Medium, Medium, Medium, Medium, Medium, Medium, Medium, Medium, Medium, Medium, High, Medium, Medium, Medium, Medium, Medium, Medium, Medium, High, High, High, Medium, High, High, High, High, High, High, High, High, High, ...]
#
# [1000 rows x 0 columns]

# %%
df2.loc['Low']
# Out:
#        index Patient Id  Age  Gender  Air Pollution  Alcohol use  \
# Level
# Low        0         P1   33       1              2            4
# Low        6       P103   52       2              2            4
# Low        7       P104   28       2              3            1
# Low       14       P110   27       2              3            1
# Low       33       P128   33       1              2            4
# ...      ...        ...  ...     ...            ...          ...
# Low      949       P953   61       1              2            3
# Low      950       P954   55       1              3            1
# Low      976       P978   33       1              2            4
# Low      977       P979   45       1              3            1
# Low      979       P980   53       1              3            1
#
#        Dust Allergy  OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# Level
# Low               5                     4             3                     2
# ...

# %%
df2.iloc[1] #the record 1
# Out:
# index                         1
# Patient Id                  P10
# Age                          17
# Gender                        1
# Air Pollution                 3
# Alcohol use                   1
# Dust Allergy                  5
# OccuPational Hazards          3
# Genetic Risk                  4
# chronic Lung Disease          2
# Balanced Diet                 2
# Obesity                       2
# Smoking                       2
# Passive Smoker                4
# Chest Pain                    2
# Coughing of Blood             3
# Fatigue                       1
# Weight Loss                   3
# Shortness of Breath           7
# Wheezing                      8
# Swallowing Difficulty         6
# Clubbing of Finger Nails      2
# Frequent Cold                 1
# Dry Cough                     7
# Snoring                       2
# Name: Medium, dtype: object

# %%
df2.iloc[1, 1] #the record 1 and columnn 1
# Out:
# 'P10'

# %%
#Order by
#-> Sorting in ascending or descending

df[df['Age']<20].sort_values(by=['Age'], ascending= True)
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 685    685       P715   14       1              2            4             5
# 352    352       P415   14       1              2            4             5
# 19      19       P115   14       1              2            4             5
# 907    907       P915   14       1              2            4             5
# 35      35        P13   14       1              2            4             5
# ..     ...        ...  ...     ...            ...          ...           ...
# 431    431       P487   19       1              6            8             7
# 360    360       P422   19       1              3            2             4
# 249    249       P322   19       1              3            2             4
# 98      98       P187   19       1              6            8             7
# 138    138       P222   19       1              3            2             4
#
# ...

# %%
df3= df.set_index('Smoking')
df3
# Out:
#          index Patient Id  Age  Gender  Air Pollution  Alcohol use  \
# Smoking
# 3            0         P1   33       1              2            4
# 2            1        P10   17       1              3            1
# 2            2       P100   35       1              4            5
# 7            3      P1000   37       1              7            7
# 8            4       P101   46       1              6            8
# ...        ...        ...  ...     ...            ...          ...
# 7          995       P995   44       1              6            7
# 7          996       P996   37       2              6            8
# 2          997       P997   25       2              4            5
# 8          998       P998   18       2              6            8
# 2          999       P999   47       1              6            5
#
#          Dust Allergy  OccuPational Hazards  Genetic Risk  \
# Smoking
# 3                   5                     4             3
# ...

# %%
df3.filter(items= 'Smoking')
# Out:
# Empty DataFrame
# Columns: []
# Index: [3, 2, 2, 7, 8, 2, 3, 1, 6, 2, 7, 7, 6, 7, 2, 8, 2, 7, 7, 5, 8, 2, 8, 7, 7, 1, 1, 2, 4, 3, 6, 7, 3, 3, 1, 5, 2, 4, 4, 6, 1, 3, 1, 3, 6, 1, 8, 2, 2, 3, 1, 2, 4, 2, 2, 2, 7, 2, 7, 4, 6, 3, 3, 3, 1, 1, 2, 3, 8, 3, 3, 1, 1, 2, 1, 1, 2, 3, 3, 7, 3, 1, 1, 1, 2, 3, 1, 7, 7, 4, 1, 8, 2, 8, 7, 7, 7, 7, 7, 2, ...]
#
# [1000 rows x 0 columns]

# %%
df3.iloc[0,0]
# Out:
# 0

# %%
df[df['Smoking']<10].sort_values(by=['Smoking'], ascending= False)
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 355    355       P418   62       1              6            8             7
# 780    780       P800   26       2              8            8             7
# 870    870       P882   46       1              6            8             7
# 868    868       P880   53       1              6            8             7
# 658    658       P691   37       1              8            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 151    151       P234   27       1              3            1             4
# 405    405       P463   48       2              2            1             5
# 145    145       P229   25       2              3            1             4
# 691    691       P720   65       1              6            8             7
# 296    296       P365   22       1              6            8             7
#
# ...

# %%
#Order by age and gender- both are set to True for ascending
df[df['Age']<80].sort_values(by= ['Age','Gender'], ascending= True)
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 19      19       P115   14       1              2            4             5
# 35      35        P13   14       1              2            4             5
# 130    130       P215   14       1              2            4             5
# 241    241       P315   14       1              2            4             5
# 352    352       P415   14       1              2            4             5
# ..     ...        ...  ...     ...            ...          ...           ...
# 570    570       P611   73       1              5            6             6
# 681    681       P711   73       1              5            6             6
# 792    792       P811   73       1              5            6             6
# 889    889         P9   73       1              5            6             6
# 903    903       P911   73       1              5            6             6
#
# ...

# %%
#Order by age and gender- One set to True for ascending and another as false
df[df['Age']<80].sort_values(by= ['Age','Gender'], ascending= [False, False])
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 15      15       P111   73       1              5            6             6
# 126    126       P211   73       1              5            6             6
# 237    237       P311   73       1              5            6             6
# 348    348       P411   73       1              5            6             6
# 459    459       P511   73       1              5            6             6
# ..     ...        ...  ...     ...            ...          ...           ...
# 352    352       P415   14       1              2            4             5
# 574    574       P615   14       1              2            4             5
# 685    685       P715   14       1              2            4             5
# 796    796       P815   14       1              2            4             5
# 907    907       P915   14       1              2            4             5
#
# ...
